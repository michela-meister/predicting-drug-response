# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [1,2,3,4]
y = x
fig = plt.figure()
plt.scatter(x, y)
plt.xlabel('x label here')
s = 'Hello World! My name is Michela and I am trying to figure out how to print a\n nice caption for \nall of my data and I wnat to see if I can print on multiple lines'
fig.text(.5, -.15, s, ha='center')
plt.show()
